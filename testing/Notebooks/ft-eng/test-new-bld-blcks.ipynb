# %%
# %load_ext autotime

# %%
import geopandas as gpd
import pandas as pd
import sys
# Out:
# time: 906 ms (started: 2021-04-23 14:48:12 +02:00)

# %%
path_root = r'C:/Users/miln/tubCloud/Work-in-progress/building-project/git-ufo-map'
sys.path.append(path_root)
from ufo_map.Utils.helpers import import_csv_w_wkt_to_gdf
from ufo_map.Feature_engineering.buildings import features_buildings_distance_based
from ufo_map.Feature_engineering.blocks import features_block_level,features_blocks_distance_based
# Out:
# time: 281 ms (started: 2021-04-23 14:48:13 +02:00)

# %%
path = r'C:\Users\miln\tubCloud\Work-in-progress\building-project\old_git\ML_paper\Data\Data samples\2.3-ft_distance_based_buildings\Udine_buildings_w_building_ft.csv'
# Out:
# time: 0 ns (started: 2021-04-23 14:48:15 +02:00)

# %%
df_buildings = import_csv_w_wkt_to_gdf(path, 7794)
# Out:
# time: 1.81 s (started: 2021-04-23 14:48:17 +02:00)

# %%
len(df_buildings)
# Out:
# 30928
# time: 0 ns (started: 2021-04-23 14:45:26 +02:00)

# %%
df_buildings = df_buildings[['osm_id', 'region', 'height', 'buffer', 'geometry', 'FootprintArea',
       'Perimeter', 'Phi', 'LongestAxisLength', 'Elongation', 'Convexity',
       'Orientation', 'Corners', 'CountTouches', 'SharedWallLength',
       'TouchesIndexes', 'BlockLength', 'AvBlockFootprintArea',
       'StdBlockFootprintArea', 'BlockTotalFootprintArea', 'BlockPerimeter',
       'BlockLongestAxisLength', 'BlockElongation', 'BlockConvexity',
       'BlockOrientation']]
# Out:
# time: 31 ms (started: 2021-04-23 14:37:45 +02:00)

# %%
features_buildings_distance_based(df_buildings,df_buildings,buffer_sizes=[100])
# Out:
# 100
# C:\Users\miln\AppData\Local\Continuum\anaconda3\envs\building-database\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\miln\AppData\Local\Continuum\anaconda3\envs\building-database\lib\site-packages\numpy\core\_methods.py:223: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
#        buildings_within_buffer_100  total_ft_area_within_buffer_100  \
# 0                             41.0                      7914.086246
# 1                             36.0                      7687.937801
# 2                             30.0                      6939.576266
# 3                             67.0                      7808.411062
# 4                             46.0                      7474.460209
# ...                            ...                              ...
# ...

# %%
features_block_level(df_buildings)
# Out:
# Retrieve blocks
# Manipulate blocks
# Features distribution buildings within block...
# Features for the whole block...
# C:/Users/miln/tubCloud/Work-in-progress/building-project/git-ufo-map\ufo_map\Utils\momepy_functions.py:323: RuntimeWarning: invalid value encountered in arccos
#   angle = np.arccos(cosine_angle)
#       TouchesIndexes  BlockLength  AvBlockFootprintArea  \
# 0                [0]            1            378.091995
# 1                [1]            1            200.588772
# 2                [2]            1            352.199650
# 3                [3]            1            214.547509
# 4                [4]            1            625.431937
# ...              ...          ...                   ...
# 30923        [30923]            1            340.756834
# 30924        [30924]            1            283.095813
# 30925        [30925]            1            742.311575
# 30926        [30926]            1            581.048924
# ...

# %%
features_blocks_distance_based(df_buildings,df_buildings,buffer_sizes=[100])
# Out:
# 100
# C:\Users\miln\AppData\Local\Continuum\anaconda3\envs\building-database\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\miln\AppData\Local\Continuum\anaconda3\envs\building-database\lib\site-packages\numpy\core\_methods.py:223: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\miln\AppData\Local\Continuum\anaconda3\envs\building-database\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\miln\AppData\Local\Continuum\anaconda3\envs\building-database\lib\site-packages\numpy\core\_methods.py:223: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# ...
